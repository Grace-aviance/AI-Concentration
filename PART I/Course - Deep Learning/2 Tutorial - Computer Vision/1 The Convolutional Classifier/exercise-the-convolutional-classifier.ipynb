# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/the-convolutional-classifier).**
#
# ---

# %% [markdown]
# # Exercise: The Convolutional Classifier #
#
# > A01285158 | Grace Aviance
# >
# > A01640495 | Carlos Alberto
#
# In the tutorial, we saw how to build an image classifier by attaching a head of dense layers to a pretrained base. The base we used was from a model called **VGG16**. We saw that the VGG16 architecture was prone to overfitting this dataset. Over this course, we'll learn a number of ways we can improve upon this initial attempt.
#
# The first way we'll see is to use a base more appropriate to the dataset. The base this model comes from is called **InceptionV1** (also known as GoogLeNet). InceptionV1 was one of the early winners of the ImageNet competition. One of its successors, InceptionV4, is among the state of the art today.
#
# To get started, run the code cell below to set everything up.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex1 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# 2024-10-03 03:02:46.812547: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-03 03:02:46.812687: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-03 03:02:46.993653: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# The **InceptionV1** model pretrained on ImageNet is available in the [TensorFlow Hub](https://www.tensorflow.org/hub/) repository, but we'll load it from a local copy. Run this cell to load InceptionV1 for your base.

# %%
import tensorflow_hub as hub

pretrained_base = tf.keras.models.load_model(
    '../input/cv-course-models/cv-course-models/inceptionv1'
)

# %% [markdown]
# # 1) Define Pretrained Base #
#
# Now that you have a pretrained base to do our feature extraction, decide whether this base should be trainable or not.

# %%
# YOUR_CODE_HERE
pretrained_base.trainable = False

# Check your answer
q_1.check()
# Out:
# Correct: When doing transfer learning, it's generally not a good idea to retrain the entire base -- at least not without some care. The reason is that the random weights in the head will initially create large gradient updates, which propogate back into the base layers and destroy much of the pretraining. Using techniques known as **fine tuning** it's possible to further train the base on new data, but this requires some care to do well.

# %% [markdown]
# # 2) Attach Head #
#
# Now that the base is defined to do the feature extraction, create a head of `Dense` layers to perform the classification, following this diagram:
#
# <figure>
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/i5VU7Ry.png" alt="Diagram of the dense head.">
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    pretrained_base,
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_2.check()
# Out:
# Correct

# %% [markdown]
# # 3) Train #
#
# Before training a model in Keras, you need to specify an *optimizer* to perform the gradient descent, a *loss function* to be minimized, and (optionally) any *performance metrics*. The optimization algorithm we'll use for this course is called ["Adam"](https://keras.io/api/optimizers/adam/), which generally performs well regardless of what kind of problem you're trying to solve.
#
# The loss and the metrics, however, need to match the kind of problem you're trying to solve. Our problem is a **binary classification** problem: `Car` coded as 0, and `Truck` coded as 1. Choose an appropriate loss and an appropriate accuracy metric for binary classification.

# %%
optimizer = tf.keras.optimizers.Adam(epsilon=0.01)
model.compile(
    optimizer=optimizer,
    loss = 'binary_crossentropy',
    metrics=['binary_accuracy'],
)

# Check your answer
q_3.check()
# Out:
# Correct

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=30,
)
# Out:
# Epoch 1/30
# 80/80 [==============================] - 102s 1s/step - loss: 0.5644 - binary_accuracy: 0.7031 - val_loss: 0.4450 - val_binary_accuracy: 0.8002
# Epoch 2/30
# 80/80 [==============================] - 89s 1s/step - loss: 0.4250 - binary_accuracy: 0.8056 - val_loss: 0.4019 - val_binary_accuracy: 0.8248
# Epoch 3/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.3930 - binary_accuracy: 0.8218 - val_loss: 0.3859 - val_binary_accuracy: 0.8289
# Epoch 4/30
# 80/80 [==============================] - 89s 1s/step - loss: 0.3752 - binary_accuracy: 0.8323 - val_loss: 0.3761 - val_binary_accuracy: 0.8345
# Epoch 5/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.3623 - binary_accuracy: 0.8401 - val_loss: 0.3695 - val_binary_accuracy: 0.8390
# Epoch 6/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.3516 - binary_accuracy: 0.8433 - val_loss: 0.3646 - val_binary_accuracy: 0.8408
# Epoch 7/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.3427 - binary_accuracy: 0.8515 - val_loss: 0.3612 - val_binary_accuracy: 0.8416
# Epoch 8/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.3349 - binary_accuracy: 0.8556 - val_loss: 0.3579 - val_binary_accuracy: 0.8434
# Epoch 9/30
# 80/80 [==============================] - 93s 1s/step - loss: 0.3277 - binary_accuracy: 0.8601 - val_loss: 0.3548 - val_binary_accuracy: 0.8464
# Epoch 10/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.3214 - binary_accuracy: 0.8646 - val_loss: 0.3524 - val_binary_accuracy: 0.8480
# Epoch 11/30
# 80/80 [==============================] - 89s 1s/step - loss: 0.3156 - binary_accuracy: 0.8675 - val_loss: 0.3503 - val_binary_accuracy: 0.8481
# Epoch 12/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.3103 - binary_accuracy: 0.8712 - val_loss: 0.3485 - val_binary_accuracy: 0.8501
# Epoch 13/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.3056 - binary_accuracy: 0.8736 - val_loss: 0.3469 - val_binary_accuracy: 0.8513
# Epoch 14/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.3009 - binary_accuracy: 0.8741 - val_loss: 0.3449 - val_binary_accuracy: 0.8519
# Epoch 15/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2965 - binary_accuracy: 0.8773 - val_loss: 0.3432 - val_binary_accuracy: 0.8515
# Epoch 16/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.2925 - binary_accuracy: 0.8798 - val_loss: 0.3419 - val_binary_accuracy: 0.8511
# Epoch 17/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2886 - binary_accuracy: 0.8812 - val_loss: 0.3405 - val_binary_accuracy: 0.8523
# Epoch 18/30
# 80/80 [==============================] - 127s 2s/step - loss: 0.2850 - binary_accuracy: 0.8829 - val_loss: 0.3392 - val_binary_accuracy: 0.8537
# Epoch 19/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2815 - binary_accuracy: 0.8843 - val_loss: 0.3378 - val_binary_accuracy: 0.8551
# Epoch 20/30
# 80/80 [==============================] - 89s 1s/step - loss: 0.2781 - binary_accuracy: 0.8865 - val_loss: 0.3365 - val_binary_accuracy: 0.8549
# Epoch 21/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2749 - binary_accuracy: 0.8892 - val_loss: 0.3353 - val_binary_accuracy: 0.8543
# Epoch 22/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2718 - binary_accuracy: 0.8904 - val_loss: 0.3340 - val_binary_accuracy: 0.8549
# Epoch 23/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2689 - binary_accuracy: 0.8904 - val_loss: 0.3331 - val_binary_accuracy: 0.8567
# Epoch 24/30
# 80/80 [==============================] - 89s 1s/step - loss: 0.2660 - binary_accuracy: 0.8911 - val_loss: 0.3324 - val_binary_accuracy: 0.8569
# Epoch 25/30
# 80/80 [==============================] - 92s 1s/step - loss: 0.2632 - binary_accuracy: 0.8927 - val_loss: 0.3314 - val_binary_accuracy: 0.8586
# Epoch 26/30
# 80/80 [==============================] - 89s 1s/step - loss: 0.2605 - binary_accuracy: 0.8935 - val_loss: 0.3309 - val_binary_accuracy: 0.8608
# Epoch 27/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.2578 - binary_accuracy: 0.8949 - val_loss: 0.3304 - val_binary_accuracy: 0.8608
# Epoch 28/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.2553 - binary_accuracy: 0.8954 - val_loss: 0.3298 - val_binary_accuracy: 0.8618
# Epoch 29/30
# 80/80 [==============================] - 90s 1s/step - loss: 0.2527 - binary_accuracy: 0.8962 - val_loss: 0.3294 - val_binary_accuracy: 0.8612
# Epoch 30/30
# 80/80 [==============================] - 91s 1s/step - loss: 0.2502 - binary_accuracy: 0.8974 - val_loss: 0.3293 - val_binary_accuracy: 0.8608

# %% [markdown]
# Run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 4) Examine Loss and Accuracy #
#
# Do you notice a difference between these learning curves and the curves for VGG16 from the tutorial? What does this difference tell you about what this model (InceptionV2) learned compared to VGG16? Are there ways in which one is better than the other? Worse?
#
# After you've thought about it, run the cell below to see the answer.

# %%
# View the solution (Run this code cell to receive credit!)
q_4.check()
# Out:
# Correct:
#
# That the training loss and validation loss stay fairly close is evidence that the model isn't just memorizing the training data, but rather learning general properties of the two classes. But, because this model converges at a loss greater than the VGG16 model, it's likely that it is underfitting some, and could benefit from some extra capacity.

# %% [markdown]
# # Conclusion #
#
# In this first lesson, you learned the basics of **convolutional image classifiers**, that they consist of a **base** for extracting features from images, and a **head** which uses the features to decide the image's class. You also saw how to build a classifier with **transfer learning** on pretrained base.

# %% [markdown]
# # Keep Going #
#
# Move on to [**Lesson 2**](https://www.kaggle.com/ryanholbrook/convolution-and-relu) for a detailed look at how the base does this feature extraction. (It's really cool!)

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
