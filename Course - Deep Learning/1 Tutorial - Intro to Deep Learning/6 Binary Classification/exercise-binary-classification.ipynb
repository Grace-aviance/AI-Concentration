# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Exercise: Binary Classification #

# %% [markdown]
# > A01285158 | Grace Aviance
# >
# > A01640495 | Carlos Alberto

# %% [markdown]
# We'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *
# Out:
# /tmp/ipykernel_33/3338970720.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(256, activation='relu'),
    layers.BatchNormalization(),
    layers.Dropout(0.3),
    layers.Dense(1, activation='sigmoid')
])

# Check your answer
q_1.check()
# Out:
# 2024-10-02 01:25:56.236507: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-02 01:25:56.236637: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-02 01:25:56.359982: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
# Check your answer
q_2.check()
# Out:
# Correct

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=65,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/65
# 175/175 [==============================] - 4s 15ms/step - loss: 0.4799 - binary_accuracy: 0.7732 - val_loss: 0.4285 - val_binary_accuracy: 0.7992
# Epoch 2/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4235 - binary_accuracy: 0.8015 - val_loss: 0.3988 - val_binary_accuracy: 0.8153
# Epoch 3/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.4102 - binary_accuracy: 0.8072 - val_loss: 0.3918 - val_binary_accuracy: 0.8214
# Epoch 4/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.4031 - binary_accuracy: 0.8113 - val_loss: 0.3871 - val_binary_accuracy: 0.8220
# Epoch 5/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3982 - binary_accuracy: 0.8132 - val_loss: 0.3861 - val_binary_accuracy: 0.8251
# Epoch 6/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3936 - binary_accuracy: 0.8173 - val_loss: 0.3795 - val_binary_accuracy: 0.8266
# Epoch 7/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3892 - binary_accuracy: 0.8180 - val_loss: 0.3775 - val_binary_accuracy: 0.8290
# Epoch 8/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3852 - binary_accuracy: 0.8207 - val_loss: 0.3724 - val_binary_accuracy: 0.8316
# Epoch 9/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3814 - binary_accuracy: 0.8213 - val_loss: 0.3712 - val_binary_accuracy: 0.8318
# Epoch 10/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3789 - binary_accuracy: 0.8252 - val_loss: 0.3686 - val_binary_accuracy: 0.8317
# Epoch 11/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3753 - binary_accuracy: 0.8250 - val_loss: 0.3660 - val_binary_accuracy: 0.8345
# Epoch 12/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3735 - binary_accuracy: 0.8270 - val_loss: 0.3739 - val_binary_accuracy: 0.8288
# Epoch 13/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3721 - binary_accuracy: 0.8271 - val_loss: 0.3640 - val_binary_accuracy: 0.8351
# Epoch 14/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3703 - binary_accuracy: 0.8294 - val_loss: 0.3614 - val_binary_accuracy: 0.8356
# Epoch 15/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3674 - binary_accuracy: 0.8300 - val_loss: 0.3603 - val_binary_accuracy: 0.8371
# Epoch 16/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3655 - binary_accuracy: 0.8296 - val_loss: 0.3604 - val_binary_accuracy: 0.8372
# Epoch 17/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3644 - binary_accuracy: 0.8308 - val_loss: 0.3586 - val_binary_accuracy: 0.8368
# Epoch 18/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3615 - binary_accuracy: 0.8325 - val_loss: 0.3577 - val_binary_accuracy: 0.8389
# Epoch 19/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3623 - binary_accuracy: 0.8329 - val_loss: 0.3580 - val_binary_accuracy: 0.8386
# Epoch 20/65
# 175/175 [==============================] - 2s 13ms/step - loss: 0.3597 - binary_accuracy: 0.8328 - val_loss: 0.3564 - val_binary_accuracy: 0.8394
# Epoch 21/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3585 - binary_accuracy: 0.8333 - val_loss: 0.3592 - val_binary_accuracy: 0.8348
# Epoch 22/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3568 - binary_accuracy: 0.8356 - val_loss: 0.3560 - val_binary_accuracy: 0.8370
# Epoch 23/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3553 - binary_accuracy: 0.8352 - val_loss: 0.3593 - val_binary_accuracy: 0.8360
# Epoch 24/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3552 - binary_accuracy: 0.8352 - val_loss: 0.3542 - val_binary_accuracy: 0.8404
# Epoch 25/65
# 175/175 [==============================] - 2s 11ms/step - loss: 0.3529 - binary_accuracy: 0.8371 - val_loss: 0.3587 - val_binary_accuracy: 0.8374
# Epoch 26/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3517 - binary_accuracy: 0.8374 - val_loss: 0.3536 - val_binary_accuracy: 0.8404
# Epoch 27/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3507 - binary_accuracy: 0.8376 - val_loss: 0.3508 - val_binary_accuracy: 0.8397
# Epoch 28/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3509 - binary_accuracy: 0.8385 - val_loss: 0.3527 - val_binary_accuracy: 0.8413
# Epoch 29/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3494 - binary_accuracy: 0.8390 - val_loss: 0.3498 - val_binary_accuracy: 0.8402
# Epoch 30/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3483 - binary_accuracy: 0.8385 - val_loss: 0.3523 - val_binary_accuracy: 0.8391
# Epoch 31/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3470 - binary_accuracy: 0.8398 - val_loss: 0.3503 - val_binary_accuracy: 0.8408
# Epoch 32/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3462 - binary_accuracy: 0.8400 - val_loss: 0.3496 - val_binary_accuracy: 0.8419
# Epoch 33/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3449 - binary_accuracy: 0.8403 - val_loss: 0.3502 - val_binary_accuracy: 0.8416
# Epoch 34/65
# 175/175 [==============================] - 2s 12ms/step - loss: 0.3449 - binary_accuracy: 0.8403 - val_loss: 0.3498 - val_binary_accuracy: 0.8422
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
